# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\jayani\Desktop\AI_Coursework\Dataset\smartcare_ai_dataset_1000.csv")

# %%
df.head()
# Out:
#    record_id patient_id  age  gender blood_group        department  \
# 0          1     P10001   53    Male          A-  General Medicine
# 1          2     P10002   26    Male          B-  General Medicine
# 2          3     P10003   22    Male          B+       Orthopedics
# 3          4     P10004   44  Female         AB-        Cardiology
# 4          5     P10005   51  Female          O+         Neurology
#
#       diagnosis appointment_date  waiting_days  previous_appointments  ...  \
# 0      Migraine       2025-04-10            10                      1  ...
# 1      Diabetes       2025-05-15             2                      3  ...
# 2     Back Pain       2025-07-09            22                      7  ...
# 3        Asthma       2025-10-16            16                      1  ...
# 4  Hypertension       2025-12-18            12                      4  ...
#
#    consultation_fee_lkr room_charge_lkr  lab_charge_lkr medicine_charge_lkr  \
# ...

# %%
df.shape
# Out:
# (1000, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   record_id                     1000 non-null   int64
#  1   patient_id                    1000 non-null   object
#  2   age                           1000 non-null   int64
#  3   gender                        1000 non-null   object
#  4   blood_group                   1000 non-null   object
#  5   department                    1000 non-null   object
#  6   diagnosis                     1000 non-null   object
#  7   appointment_date              1000 non-null   object
#  8   waiting_days                  1000 non-null   int64
#  9   previous_appointments         1000 non-null   int64
#  10  missed_previous_appointments  1000 non-null   int64
#  11  appointment_status            1000 non-null   object
# ...

# %%
df.describe()
# Out:
#          record_id          age  waiting_days  previous_appointments  \
# count  1000.000000  1000.000000   1000.000000            1000.000000
# mean    500.500000    44.744000     21.851000               2.884000
# std     288.819436    17.851474     13.040892               1.693343
# min       1.000000     1.000000      0.000000               0.000000
# 25%     250.750000    33.000000     11.000000               2.000000
# 50%     500.500000    44.000000     22.000000               3.000000
# 75%     750.250000    57.000000     34.000000               4.000000
# max    1000.000000    90.000000     44.000000              10.000000
#
#        missed_previous_appointments     admitted  length_of_stay_days  \
# count                   1000.000000  1000.000000          1000.000000
# mean                       0.553000     0.330000             1.103000
# std                        0.740094     0.470448             1.885191
# ...

# %%
df.columns
# Out:
# Index(['record_id', 'patient_id', 'age', 'gender', 'blood_group', 'department',
#        'diagnosis', 'appointment_date', 'waiting_days',
#        'previous_appointments', 'missed_previous_appointments',
#        'appointment_status', 'admitted', 'room_type', 'length_of_stay_days',
#        'previous_admissions', 'systolic_bp', 'diastolic_bp',
#        'blood_sugar_mg_dl', 'cholesterol_mg_dl', 'bmi', 'lab_tests_count',
#        'treatments_count', 'consultation_fee_lkr', 'room_charge_lkr',
#        'lab_charge_lkr', 'medicine_charge_lkr', 'total_bill_lkr',
#        'payment_status', 'payment_method', 'no_show', 'readmitted_30_days',
#        'disease_risk_level'],
#       dtype='object')

# %%
print(df["no_show"].head())
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: no_show, dtype: int64

# %%
df.isnull().sum()
# Out:
# record_id                         0
# patient_id                        0
# age                               0
# gender                            0
# blood_group                       0
# department                        0
# diagnosis                         0
# appointment_date                  0
# waiting_days                      0
# previous_appointments             0
# missed_previous_appointments      0
# appointment_status                0
# admitted                          0
# room_type                       906
# length_of_stay_days               0
# previous_admissions               0
# systolic_bp                       0
# diastolic_bp                      0
# blood_sugar_mg_dl                 0
# cholesterol_mg_dl                 0
# bmi                               0
# lab_tests_count                   0
# treatments_count                  0
# consultation_fee_lkr              0
# room_charge_lkr                   0
# lab_charge_lkr                    0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes
# Out:
# record_id                         int64
# patient_id                       object
# age                               int64
# gender                           object
# blood_group                      object
# department                       object
# diagnosis                        object
# appointment_date                 object
# waiting_days                      int64
# previous_appointments             int64
# missed_previous_appointments      int64
# appointment_status               object
# admitted                          int64
# room_type                        object
# length_of_stay_days               int64
# previous_admissions               int64
# systolic_bp                       int64
# diastolic_bp                      int64
# blood_sugar_mg_dl                 int64
# cholesterol_mg_dl                 int64
# bmi                             float64
# lab_tests_count                   int64
# treatments_count                  int64
# ...

# %%
df.nunique()
# Out:
# record_id                       1000
# patient_id                      1000
# age                               88
# gender                             2
# blood_group                        8
# department                         7
# diagnosis                         10
# appointment_date                 339
# waiting_days                      45
# previous_appointments             10
# missed_previous_appointments       5
# appointment_status                 4
# admitted                           2
# room_type                          3
# length_of_stay_days               10
# previous_admissions                6
# systolic_bp                       83
# diastolic_bp                      58
# blood_sugar_mg_dl                120
# cholesterol_mg_dl                172
# bmi                              197
# lab_tests_count                   11
# treatments_count                  11
# consultation_fee_lkr               6
# room_charge_lkr                   22
# ...
